# %% [markdown]
# ## Ladda och omarbeta Prisindex

# %%
## Om det körs i samma pipeline, behövs det inte köras igen. 
## %run 0.Hämta_Lämna_Minio.ipynb

# %%
bucket_namn = "demo-funktionalitet"
file_index = "index_orig.sas7bdat"
file_vikter = "value_orig.sas7bdat"
prisindex1 = read_from_s3(bucket_namn, file_index, datatype="sas")
vikter = read_from_s3(bucket_namn, file_vikter, datatype="sas")

# %%
prisindex1.head()
# Out:
#    factKlonKey   Period  VariableId VariableName  MeasureValue  BranchGroupId  \
# 0  229117764.0  2013M08         3.0    Prisindex          99.8          143.0
# 1  229109145.0  2013M11         3.0    Prisindex          99.9          143.0
# 2  229101477.0  2006M09         3.0    Prisindex          94.9          143.0
# 3  229122072.0  2002M11         3.0    Prisindex          84.2          143.0
# 4  229106841.0  2006M03         3.0    Prisindex          90.9          143.0
#
#                                       BranchName BranchCode    OutClass  \
# 0  Elmotorer, generat. batterier, kablar, belys.   27.1-4,9  27.1-4,9|5
# 1  Elmotorer, generat. batterier, kablar, belys.   27.1-4,9  27.1-4,9|5
# 2  Elmotorer, generat. batterier, kablar, belys.   27.1-4,9  27.1-4,9|5
# 3  Elmotorer, generat. batterier, kablar, belys.   27.1-4,9  27.1-4,9|5
# 4  Elmotorer, generat. batterier, kablar, belys.   27.1-4,9  27.1-4,9|5
#
#    IsFinal MarknadCode            MarknadName
# ...

# %%
vikter.tail()
# Out:
#         factKlonKey   Period  VariableId VariableName  MeasureValue  \
# 35187  2.721774e+08  2015M05        17.0   Omsättning  4.250600e+04
# 35188  2.095980e+08  2007M08        17.0   Omsättning  0.000000e+00
# 35189  1.229886e+09  2022M03        17.0   Omsättning  3.718888e+06
# 35190  1.229886e+09  2022M03        17.0   Omsättning  3.350718e+05
# 35191  1.229886e+09  2022M03        17.0   Omsättning  8.953016e+03
#
#        BranchGroupId                                         BranchName  \
# 35187         3360.0               Övrig tillverkning av transportmedel
# 35188         3360.0               Övrig tillverkning av transportmedel
# 35189         3889.0  Tillverkning av datorer , kommunikationsutrust...
# 35190         2670.0    Industri för datorer, elektronikvaror och optik
# 35191         4986.0                           Industri för elapparatur
#
#       BranchCode     OutClass  IsFinal AttributeCode  \
# 35187       30.9    30.9|5|07      1.0      6.1.1.10
# ...
