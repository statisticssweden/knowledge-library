# %%
# ***********************************************************************************************
# Titel: Exempel på diagramtyper i R - MULTIPLA DIAGRAM
# Beskrivning: Illustrera exempel med diagramtyper i R
# Skapad av: Frank Weideskog(frank.weideskog@scb.se), ID: SCBFRWE
# 2024-06-17 (SCBFRWE):En första version 
#*************************************************************************************************
# Rensar minnet i R
rm(list=ls())				
# ************************************************************************************************
#Installerar/aktiverar relevanta R-paket (R-packages):
#R-Base"
# ************************************************************************************************


#MULTIPLA DIAGRAM

text<- 'Att arrangera multipla diagram på en sida i R är en vanligt när man vill jämföra olika visualiseringar eller presentera flera resultat i en rapport eller presentation. Det finns flera sätt att göra detta. Här följer två vanliga metoder:'
text

# Dela upp grafikfönstret i 2 rader och 2 kolumner
par(mfrow = c(2, 2))

# Diagrammen kommer att placeras i rutnätet 2x2 (två diagram på två rader)
plot(1:10)
hist(rnorm(100))
boxplot(iris$Sepal.Length)
barplot(table(iris$Species))

text<- '1) Med par()-funktionen: par()-funktionen används för att dela upp den grafiska enheten i flera fönster och placera flera diagram på en sida.'
text

# Ange layouten för diagrammen (alla fyra på en rad)
layout(matrix(c(1,2,3,4), 2, 4, byrow = TRUE))

# Diagrammen kommer att placeras enligt den angivna layouten
plot(1:10)
hist(rnorm(100))
boxplot(iris$Sepal.Length)
barplot(table(iris$Species))

text<- '2) Med layout()-funktionen: layout()-funktionen ger mer flexibilitet för att anpassa layouten av diagrammen på sidan.'
text
# Out:
# [1] "Att arrangera multipla diagram på en sida i R är en vanligt när man vill jämföra olika visualiseringar eller presentera flera resultat i en rapport eller presentation. Det finns flera sätt att göra detta. Här följer två vanliga metoder:"
# [1] "1) Med par()-funktionen: par()-funktionen används för att dela upp den grafiska enheten i flera fönster och placera flera diagram på en sida."
# Plot with title “Histogram of rnorm(100)”
# [1] "2) Med layout()-funktionen: layout()-funktionen ger mer flexibilitet för att anpassa layouten av diagrammen på sidan."
# Plot with title “Histogram of rnorm(100)”
