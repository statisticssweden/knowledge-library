# %%
# ***********************************************************************************************
# Titel: Exempel på diagramtyper i R - FACETTERADE DIAGRAM
# Beskrivning: Illustrera exempel med diagramtyper i R
# Skapad av: Frank Weideskog(frank.weideskog@scb.se), ID: SCBFRWE
# 2024-06-17 (SCBFRWE):En första version 
#*************************************************************************************************
# Rensar minnet i R
rm(list=ls())				
# ************************************************************************************************
#Installerar/aktiverar relevanta R-paket (R-packages):
suppressMessages({
  install.packages("ggplot2")
  library(ggplot2)
})   
# ************************************************************************************************
suppressPackageStartupMessages(library(ggplot2))

#FACETTERADE DIAGRAM

p1 <- qplot(mpg, wt, data = mtcars, colour = cyl)
p2 <-
  p1 + facet_wrap( ~ carb, nrow = 1) + theme(legend.position = "none") +
  ggtitle("Facetterad plot")
p2
text<- 'Facetterade diagram i R är en typ av visualisering där man delar upp en plot i flera paneler, var och en representerar en undergrupp av data. Detta är användbart när man har en dataset med en eller flera kategoriska variabler och du vill jämföra samma typ av plot över olika grupper av data.'
text
# Out:
# [1] "Facetterade diagram i R är en typ av visualisering där man delar upp en plot i flera paneler, var och en representerar en undergrupp av data. Detta är användbart när man har en dataset med en eller flera kategoriska variabler och du vill jämföra samma typ av plot över olika grupper av data."
# plot without title
