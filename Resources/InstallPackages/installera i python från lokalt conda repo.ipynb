# %% [markdown]
# # Installera Python
# För kännedom, både CRAN- och condaspeglar finns lokalt och kan kommas åt från Balsam. För att installera från CRAN skriver ni i en notebook med R-kernel

# %%
conda install -c "http://tsta251.scb.intra/conda" --override-channels pyarrow
# Out:
# ...
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::libedit==3.1.20191231=he28a2e2_2
#   - conda-forge/linux-64::r-rcurl==1.98_1.12=r42h133d619_0
#   - conda-forge/linux-64::r-profvis==0.3.7=r42h06615bd_1
#   - conda-forge/noarch::r-desc==1.4.2=r42hc72bb7e_1
#   - conda-forge/noarch::r-highr==0.10=r42hc72bb7e_0
#   - conda-forge/linux-64::r-proc==1.18.0=r42h7525677_1
#   - conda-forge/noarch::r-xtable==1.8_4=r42hc72bb7e_4
#   - conda-forge/noarch::r-rvest==1.0.3=r42hc72bb7e_1
#   - conda-forge/linux-64::r-isoband==0.2.7=r42h38f115c_1
#   - conda-forge/linux-64::unixodbc==2.3.10=h583eb01_0
#   - conda-forge/noarch::r-hardhat==1.3.0=r42hc72bb7e_0
#   - conda-forge/noarch::r-future.apply==1.10.0=r42hc72bb7e_0
#   - conda-forge/linux-64::r-arrow==10.0.1=r42hcb278e6_0
#   - conda-forge/linux-64::r-fracdiff==1.5_2=r42h64d53c3_0
# ...

# %% [markdown]
# ## Testa att installera ett Python paket pandas från Conda.

# %%
conda install -c "http://tsta251.scb.intra/conda" pandas
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.7.4
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |   py39h7deecbd_0         126 KB  http://tsta251.scb.intra/conda
#     ca-certificates-2023.05.30 |       h06a4308_0         127 KB  http://tsta251.scb.intra/conda
#     certifi-2023.7.22          |   py39h06a4308_0         155 KB  http://tsta251.scb.intra/conda
#     nomkl-1.0                  |       h5ca1d4c_0           4 KB  conda-forge
#     numexpr-2.8.7              | py39hddac248_100         129 KB  conda-forge
# ...

# %%
import pandas as pd
